# %% [markdown]
# # Exploratory Data Analysis
# Analysing affordable housing projects in California with Low-Income Housing Tax Credit (LIHTC)
# - Objective: What is the common characteristics of the awarded projects?

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("../data/award_list.xlsx")

# %%
data.shape
# Out:
# (38, 42)

# %%
data.head()
# Out:
#   APPLICATION NUMBER               PROJECT NAME CONSTRUCTION TYPE  \
# 0          CA-25-404  TBV Villas at Renaissance  New Construction
# 1          CA-25-406              10953 Whipple  New Construction
# 2          CA-25-407             5403 Inglewood  New Construction
# 3          CA-25-409          9030-9038 Reading  New Construction
# 4          CA-25-410         11218-11222 Califa  New Construction
#
#    HOUSING TYPE         CITY        COUNTY  TOTAL UNITS  LOW INCOME UNITS  \
# 0  Large Family     Richmond  Contra Costa          105               104
# 1  Non-Targeted  Los Angeles   Los Angeles           91                90
# 2  Non-Targeted  Los Angeles   Los Angeles           46                45
# 3  Non-Targeted  Los Angeles   Los Angeles           77                76
# 4  Non-Targeted  Los Angeles   Los Angeles           76                75
#
#    MARKET RATE UNITS  TOTAL PROJECT COST  ...            PARTNERSHIP NAME  \
# ...

# %%
data2 = pd.read_excel("../data/2025-Applicant-list-4-per-R1.xlsx")

# %%
data2.shape
# Out:
# (92, 46)

# %%
data2.head()
# Out:
#   *The project information provided on this document is “as applied” in the application and has not been verified by CDLAC and CTCAC staff.   \
# 0                                 APPLICATION NUMBER
# 1                                          CA-25-404
# 2                                          CA-25-405
# 3                                          CA-25-406
# 4                                          CA-25-407
#
#                             Unnamed: 1              Unnamed: 2    Unnamed: 3  \
# 0                         PROJECT NAME       CONSTRUCTION TYPE  HOUSING TYPE
# 1            TBV Villas at Renaissance        New Construction  Large Family
# 2  Adda and Paul Safran Senior Housing  Acq and Rehabilitation  Non-Targeted
# 3                        10953 Whipple        New Construction  Non-Targeted
# 4                       5403 Inglewood        New Construction  Non-Targeted
#
#     Unnamed: 4    Unnamed: 5   Unnamed: 6        Unnamed: 7  \
# ...

# %% [markdown]
# ### Notes
# - 90 applications, 37 awarded
# - 42 columns
